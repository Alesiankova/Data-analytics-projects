# %% [markdown]
# The task was performed by Alesiankova Darya
# Date: 20.02.2023
# _____________________________

# %% [markdown]
# # Data Taxonomy Organization Task - Whisk
#
#
# For this exercise, we’d like to see how you would approach organizing documentation for product analytics events.
#
# Your response should reflect the following considerations:
#
# - Whisk’s tracking system includes several hundred events.
# - Each event might have several common properties (called context) and several properties that are unique to a particular event.
# - Users of this documentation include engineers who implement these events in our applications and data analysts/product managers who use the data to build charts. Think about what information can be useful to include for these roles in your documentation.
# - Events will be modified over time as our tracking needs evolve. Events may also have different versions across platforms.
#
# It’s not necessary to present the perfect structure – instead, prioritize communicating your concept and describe how it could be improved in the future.
# Feel free to use any tools, structured or visual. Some examples could be Excel, Notion, Miro, and Figma.
#
# **An instance of one event, for reference:**
#
# {
# date_time: ""2023-02-17T11:58:49+0000"",
# app_name: ""ios"",
# app_version: ""v23.01"",
# user_id: ""72d55ffe-8072-4ed6-8bce-7388c7903937"",
# event_name: ""Recipe Viewed"",
# Page_name: ""Recipe Page"",
# recipe_id: ""28479f28-1c41-457a-bd85-fdcef1ef139a"",
# recipe_url: ""Pineapple Pizza"",
# }

# %% [markdown]
# <div class="alert alert-info">Create a taxonomy of event categories</div>

# %% [markdown]
# - If Whisk's tracking system includes several hundred events, it may not be practical to include all events in a single table.
#
# - Instead, the events could be organized into categories based on their functionality or business goals and objectives.
#
# - Each group of events could then have its own table, with a similar structure to the example provided. This would allow for easier navigation and management of the documentation.
#
# * Additionally, it may be helpful to include a search functionality to help users quickly find specific events or categories of events they are interested in. Or add tags to events to group them by common themes.
#
# For example:
#
# ______________________
# ### **Main categories:**
# - User events (e.g., Recipe viewed, Recipe saved)
# - Marketing events (e.g., push notification opened)
# - System events (e.g., App launched, Session started)
# - Errors (e.g., Invalid input, Server error)
# _______________________
#
# ### **Subcategories:**
# `User actions:`
# - User behavior-related (e.g., Recipe viewed, Recipe saved, Recipe created, Search, Ingredient viewed, Recipe rating)
# - Shopping-related (e.g., Item added to cart, Shopping list created, Order confirmation)
# - Account-related (e.g., User registered, User logged in)
#
# ____________________
# `Marketing events:`
# - Email campaigns events ( e.g., followed the link in the email)
# - Push notifications events ( e.g.,push notification opened)
# - Referral events
#
# ________________
# `System events:`
# - App-related (e.g., App launched, App updated, App installation, App uninstallation)
# - Session-related (e.g., Session started, Session ended)
# ________________
# `Errors:`
# - Input-related (e.g., Invalid email address, Missing required field)
# - Server-related (e.g., Server error, Database connection error)

# %% [markdown]
# <div class="alert alert-info">Сommon properties (context) and unique properties</div>

# %% [markdown]
# If each event has several common properties (context) and several unique properties, it may be helpful to structure the table in a way that separates the two types of properties. For example, we could create two columns: one for the common properties (context) and another for the unique properties.
#
# **For each event, I would document the following information:**
#
# - **Event name**: the name of the event, which should be descriptive, standardized, and easily understandable
# - **Description**: A brief description of the event's purpose and functionality
# - **Event Category/Subcategories:** The category of the event (e.g., User events, System events, etc.)
# - **Context properties**: a list of properties that are common to all events in the same category. For example, all User actions events might include a date_time and app name.
# - **Unique properties**: a list of properties that are unique to the event. For example, a recipe viewed event have to include a recipe id and recipe URL.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <div class="alert alert-info">Additional information that may be useful to engineers and data analysts/product managers</div>

# %% [markdown]
# **For engineers who implement these events in applications, the documentation should include technical information such as:**
#
# - Event ID or unique identifier
# - The data types and formats for each property
# - The possible values for each property (if applicable)
# - Any dependencies or relationships between events
# - The expected data volume or frequency for the event
# - Any data quality or validation checks that need to be performed
# - Any relevant error messages and troubleshooting tips
# - Implementation instructions and code examples of how to implement each event in different platforms.
# - Version History: A record of any changes or modifications to the event over time, including the date, version number, and description of the change.
# ________________
# **For data analysts and product managers who use the data to build charts and make decisions, the documentation should focus on the business context and usage of the data. so I would like to add information about:**
#
# - The business questions or goals that each event is intended to support
# - The key metrics or KPIs that can be derived from the data
# - Any relevant dashboards or reports that use the event data
# - Any transformations or calculations that are performed on the event data
# - The types of questions that the event data can help answer
# - Important notes about the data
# __________________
#
# These event specifications should maintain in a shared document repository that is accessible to all relevant stakeholders.

# %% [markdown]
# **Additionally, it may be helpful to provide documentation on the data schema and how the different events relate to each other. This could include information such as entity-relationship diagrams or other visualizations that show the relationships between different events and properties.**
#
# *I didn't create this diagram. This is just an example as it may looks like*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### In addition, i think  the structure of the taxonomy can be improved in several ways, including:
#
# - Establishing a version control system to track changes to events and ensure that documentation is up-to-date
# - Cross-platform documentation: Given that events may have different versions across platforms, it's important to maintain a consistent documentation system that reflects the similarities and differences between versions. This could involve creating separate documentation for each platform or maintaining a single, cross-platform documentation system that clearly highlights the differences between versions.
# - Clear documentation: It's important to document changes to events clearly and concisely, including the rationale for the change, any impact on downstream data or systems, and any changes to required or optional properties. This documentation should be accessible to all relevant stakeholders, including engineers, data analysts, and product managers.
# - Conducting regular reviews and updates to ensure that documentation remains relevant and accurate
# - Seeking feedback from stakeholders to identify areas for improvement or refinement of the taxonomy structure.

# %% [markdown]
# # Analytics Bug Investigation Task (as an option)
#
# Imagine we have a relational database that contains application events. There is 1 year of
# historical data. The database table is called “events” and has the following schema:
#
# CREATE TABLE events (
# id INT AUTO_INCREMENT PRIMARY KEY,
# date_time DATETIME NOT NULL,
# app_name VARCHAR(20) NOT NULL,
# app_version VARCHAR(10) NOT NULL,
# user_id VARCHAR(36) NOT NULL,
# event_name VARCHAR(255) NOT NULL,
# page_name VARCHAR(255),
# recipe_id VARCHAR(36),
# recipe_url VARCHAR(255)
# );
#
# Someone from our team reported that one of the events, “Recipe Viewed,” is not sent in some
# cases when it was expected to be tracked.
#
# **Your task is to come up with a SQL query (or several queries) and a visual chart based on that
# query that will help you to understand whether this is a bug or not. Use the table “events.” In
# your queries, try to address the following:**
#
# - What kind of additional information, useful for the QA team, can you gather from
# historical data?
# - Consider that we have several platforms (iOS, Android, web) and different versions of
# applications on each platform.
# You can use any kind of SQL-like syntax in your response.

# %% [markdown]
# <div class="alert alert-info">"Recipe viewed" event across platforms and app versions</div>

# %% [markdown]
# For example - This query will give us the number of "Recipe Viewed" events and other events for each platform and version. We can use this information to identify patterns or trends that might be related to the bug.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-info">An example of the table that we will receive:</div>

# %%
df_app = pd.read_csv('data_app.csv', sep=';')
df_app
# Out:
#   app_name app_version  total_events  viewed_events  other_events
# 0  Android      v11.01          1756            210          1546
# 1  Android      v11.02          2590            336          2254
# 2  Android      v11.03          3003            420          2583
# 3  Android      v11.04           800             78           722
# 4      ios      v23.01          2201            264          1937
# 5      ios      v23.02          2034            223          1811
# 6      ios      v23.03          3546            460          3086
# 7      ios      v23.04          1432            214          1218
# 8      Web       v1.01           987            108           879

# %% [markdown]
# - This query will give us the number of events for each platform and app version in the last year, as well as the number of Recipe View events and the number of other events.
# - We can use this information to calculate the Recipe View event rate and see if it is significantly lower on any platform or version.

# %% [markdown]
# <div class="alert alert-info"> Calculation the percentage of "Recipe Viewed" events</div>

# %% [markdown]
# - %_of_total - show percentage "Recipe Viewed" from the total number of events
# - %_of_other - show percentage "Recipe Viewed" of other events

# %%
df_app['%_of_total'] = df_app['viewed_events']/df_app['total_events']
df_app['%_of_other'] = df_app['viewed_events']/df_app['other_events']
df_app
# Out:
#   app_name app_version  total_events  viewed_events  other_events  %_of_total  \
# 0  Android      v11.01          1756            210          1546    0.119590
# 1  Android      v11.02          2590            336          2254    0.129730
# 2  Android      v11.03          3003            420          2583    0.139860
# 3  Android      v11.04           800             78           722    0.097500
# 4      ios      v23.01          2201            264          1937    0.119945
# 5      ios      v23.02          2034            223          1811    0.109636
# 6      ios      v23.03          3546            460          3086    0.129724
# 7      ios      v23.04          1432            214          1218    0.149441
# 8      Web       v1.01           987            108           879    0.109422
#
#    %_of_other
# 0    0.135834
# 1    0.149068
# 2    0.162602
# 3    0.108033
# 4    0.136293
# 5    0.123136
# 6    0.149060
# 7    0.175698
# 8    0.122867

# %% [markdown]
# <div class="alert alert-info"> Calculation the percentage of "Recipe Viewed" events</div>

# %%
df_app['app_name_version'] = df_app['app_name'] + ' ' + df_app['app_version']
df_app[['app_name_version', '%_of_total', '%_of_other']].plot(kind='bar', x = 'app_name_version')
# Out:
# <AxesSubplot:xlabel='app_name_version'>

# %% [markdown]
# <div class="alert alert-info"> Сonclusions</div>

# %% [markdown]
# - On the test data, we can see that a bug is possible in Android v11.04. Percentage of Recipe View events is too low compared to other versions of the app. You can also check iOS v23.02.
#
# - On real data, I would look at how this percentage has changed over time. I would find out how long ago such changes took place or they were originally in this version of the application.
#
# - I would also look at the "Recipe View" conversion to the events that go with it. Before or after it. Such as "Recipe Search" for example.
#
# - Error events: By analyzing error events, we can identify if there were any issues with the tracking system or if there were any errors that prevented the "Recipe Viewed" event from being tracked.
